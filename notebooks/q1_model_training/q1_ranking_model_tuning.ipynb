# %% [markdown]
# # Import libraries

# %%
import os
import numpy as np

from keras import callbacks
import keras_tuner as kt

from src.data_aug import data_aug_with_random_contrast
from src.ranking_model_prob import create_meta_network

# %% [markdown]
# # Prepare data

# %%
# Configure question index
question_index = str(1)

# Load training data
training_data_path = 'data/ForModelTraining/train_data/draw_exclude'
img_left_training = np.load(os.path.join(training_data_path + '/train_left_duel_' + question_index + '.npy'), allow_pickle=True)
img_right_training = np.load(os.path.join(training_data_path + '/train_right_duel_' + question_index + '.npy'), allow_pickle=True)
label_training = np.load(os.path.join(training_data_path + '/train_label_duel_' + question_index + '.npy'), allow_pickle=True)

# Load validation data
validation_data_path = 'data/ForModelTraining/validation_data/draw_exclude'
img_left_validation = np.load(os.path.join(validation_data_path + '/val_left_duel_' + question_index + '.npy'), allow_pickle=True)
img_right_validation = np.load(os.path.join(validation_data_path + '/val_right_duel_' + question_index + '.npy'), allow_pickle=True)
label_validation = np.load(os.path.join(validation_data_path + '/val_label_duel_' + question_index + '.npy'), allow_pickle=True)

# Load test data
test_data_path = 'data/ForModelTraining/test_data/draw_exclude'
img_left_test = np.load(os.path.join(test_data_path + '/test_left_duel_' + question_index + '.npy'), allow_pickle=True)
img_right_test = np.load(os.path.join(test_data_path + '/test_right_duel_' + question_index + '.npy'), allow_pickle=True)
label_test = np.load(os.path.join(test_data_path + '/test_label_duel_' + question_index + '.npy'), allow_pickle=True)

# %%
print(img_left_training)
# Out:
# [[[[ 59.  71.  71.]
#    [ 51.  61.  62.]
#    [ 47.  57.  59.]
#    ...
#    [ 40.  31.  26.]
#    [ 44.  35.  30.]
#    [ 47.  38.  33.]]
#
#   [[ 65.  76.  80.]
#    [ 38.  49.  53.]
#    [ 62.  73.  79.]
#    ...
#    [ 40.  31.  26.]
#    [ 42.  33.  28.]
#    [ 44.  35.  30.]]
#
#   [[ 91. 101. 111.]
#    [ 70.  80.  90.]
#    [ 51.  61.  73.]
#    ...
#    [ 41.  32.  27.]
#    [ 42.  33.  28.]
#    [ 43.  34.  29.]]
#
#   ...
#
#   [[ 49.  45.  62.]
#    [ 51.  47.  64.]
#    [ 53.  49.  66.]
#    ...
#    [ 35.  35.  27.]
#    [ 34.  34.  26.]
#    [ 34.  34.  26.]]
#
#   [[ 56.  52.  69.]
#    [ 57.  53.  70.]
#    [ 57.  53.  70.]
#    ...
#    [ 35.  35.  27.]
#    [ 33.  33.  25.]
#    [ 32.  32.  24.]]
#
#   [[ 57.  53.  70.]
#    [ 53.  49.  66.]
#    [ 51.  47.  64.]
#    ...
#    [ 35.  35.  27.]
#    [ 33.  33.  25.]
#    [ 31.  31.  23.]]]
#
#
#  [[[104. 114.  41.]
#    [107. 116.  53.]
#    [ 88.  94.  48.]
#    ...
#    [134. 147. 215.]
#    [134. 147. 215.]
#    [134. 147. 215.]]
#
#   [[ 61.  68.  14.]
#    [ 72.  79.  28.]
#    [ 77.  82.  42.]
#    ...
#    [134. 147. 215.]
#    [134. 147. 215.]
#    [134. 147. 215.]]
#
#   [[ 65.  68.  39.]
#    [ 69.  72.  41.]
#    [ 80.  81.  49.]
#    ...
#    [134. 147. 215.]
#    [134. 147. 215.]
#    [134. 147. 215.]]
#
#   ...
#
#   [[ 19.  17.  30.]
#    [ 19.  17.  30.]
#    [ 18.  16.  29.]
#    ...
#    [119. 115.  67.]
#    [146. 142.  95.]
#    [111. 107.  60.]]
#
#   [[ 16.  14.  27.]
#    [ 20.  18.  31.]
#    [ 24.  22.  35.]
#    ...
#    [115. 111.  63.]
#    [126. 122.  74.]
#    [138. 134.  86.]]
#
#   [[ 23.  21.  34.]
#    [ 17.  15.  28.]
#    [ 12.  10.  23.]
#    ...
#    [135. 131.  83.]
#    [115. 111.  63.]
#    [110. 104.  56.]]]
#
#
#  [[[255. 255. 255.]
#    [255. 255. 255.]
#    [255. 255. 255.]
#    ...
#    [ 97. 100. 105.]
#    [ 60.  63.  68.]
#    [ 93.  96. 101.]]
#
#   [[255. 255. 255.]
#    [255. 255. 255.]
#    [255. 255. 255.]
#    ...
#    [ 70.  73.  78.]
#    [ 83.  86.  91.]
#    [ 98. 101. 106.]]
#
#   [[255. 255. 255.]
#    [255. 255. 255.]
#    [255. 255. 255.]
#    ...
#    [ 90.  91.  96.]
#    [ 99. 100. 105.]
#    [ 90.  91.  96.]]
#
#   ...
#
#   [[ 64.  82.  44.]
#    [ 65.  83.  45.]
#    [ 70.  88.  50.]
#    ...
#    [ 93.  90.  73.]
#    [ 99.  97.  82.]
#    [ 89.  87.  72.]]
#
#   [[ 64.  82.  42.]
#    [ 69.  87.  47.]
#    [ 80.  98.  58.]
#    ...
#    [ 98.  95.  80.]
#    [108. 104.  92.]
#    [100.  96.  84.]]
#
#   [[ 71.  89.  49.]
#    [ 66.  84.  44.]
#    [ 66.  84.  44.]
#    ...
#    [101.  97.  85.]
#    [112. 108.  96.]
#    [105. 101.  89.]]]
#
#
#  ...
#
#
#  [[[138. 202. 250.]
#    [135. 201. 249.]
#    [134. 200. 252.]
#    ...
#    [255. 255. 255.]
#    [255. 255. 255.]
#    [255. 255. 255.]]
#
#   [[140. 203. 247.]
#    [140. 202. 249.]
#    [138. 202. 250.]
#    ...
#    [255. 255. 255.]
#    [255. 255. 255.]
#    [255. 255. 255.]]
#
#   [[141. 198. 241.]
#    [141. 198. 241.]
#    [141. 199. 245.]
#    ...
#    [255. 255. 255.]
#    [255. 255. 255.]
#    [255. 255. 255.]]
#
#   ...
#
#   [[ 61.  59.  62.]
#    [ 64.  62.  65.]
#    [ 69.  67.  72.]
#    ...
#    [111. 106. 103.]
#    [108. 103. 100.]
#    [103.  98.  95.]]
#
#   [[ 59.  57.  62.]
#    [ 61.  58.  65.]
#    [ 65.  62.  69.]
#    ...
#    [123. 115. 113.]
#    [118. 113. 110.]
#    [122. 117. 114.]]
#
#   [[ 87.  84.  91.]
#    [ 67.  64.  71.]
#    [ 50.  47.  56.]
#    ...
#    [113. 105. 103.]
#    [112. 107. 104.]
#    [114. 109. 106.]]]
#
#
#  [[[122. 134. 184.]
#    [129. 142. 194.]
#    [122. 138. 190.]
#    ...
#    [ 68.  71.  44.]
#    [ 77.  80.  53.]
#    [ 91.  95.  68.]]
#
#   [[ 86. 100. 149.]
#    [114. 130. 179.]
#    [106. 126. 177.]
#    ...
#    [ 67.  70.  43.]
#    [ 82.  86.  61.]
#    [ 92.  96.  71.]]
#
#   [[ 88. 109. 154.]
#    [114. 136. 183.]
#    [122. 145. 195.]
#    ...
#    [ 71.  75.  48.]
#    [ 66.  70.  45.]
#    [ 50.  54.  31.]]
#
#   ...
#
#   [[169. 163. 165.]
#    [175. 169. 171.]
#    [169. 163. 165.]
#    ...
#    [136. 154.  80.]
#    [141. 152.  83.]
#    [121. 130.  63.]]
#
#   [[171. 165. 167.]
#    [187. 181. 183.]
#    [182. 176. 178.]
#    ...
#    [125. 143.  69.]
#    [132. 143.  74.]
#    [109. 116.  49.]]
#
#   [[172. 166. 168.]
#    [187. 181. 183.]
#    [185. 179. 181.]
#    ...
#    [124. 140.  67.]
#    [136. 146.  77.]
#    [114. 119.  53.]]]
#
#
#  [[[199. 229. 201.]
#    [160. 191. 159.]
#    [141. 176. 136.]
#    ...
#    [221. 233. 249.]
#    [182. 191. 198.]
#    [197. 203. 203.]]
#
#   [[154. 182. 157.]
#    [159. 190. 159.]
#    [149. 181. 144.]
#    ...
#    [193. 205. 221.]
#    [211. 220. 227.]
#    [217. 226. 225.]]
#
#   [[207. 235. 213.]
#    [167. 195. 170.]
#    [117. 146. 116.]
#    ...
#    [226. 239. 255.]
#    [247. 255. 255.]
#    [217. 227. 228.]]
#
#   ...
#
#   [[ 83.  80.  91.]
#    [ 80.  77.  88.]
#    [ 79.  76.  87.]
#    ...
#    [ 34.  24.  25.]
#    [ 36.  27.  28.]
#    [ 36.  30.  30.]]
#
#   [[ 88.  85.  96.]
#    [ 84.  81.  92.]
#    [ 82.  79.  90.]
#    ...
#    [ 35.  23.  25.]
#    [ 35.  27.  25.]
#    [ 36.  31.  28.]]
#
#   [[ 76.  73.  84.]
#    [ 78.  75.  86.]
#    [ 82.  79.  90.]
#    ...
#    [ 34.  20.  20.]
#    [ 32.  22.  21.]
#    [ 34.  26.  24.]]]]

# %% [markdown]
# ## Augment data with random contrast
# *This is a data augmentation method that raised by Hannick. It helps to improve the model performance.*
# [Hannick's GitHub](https://github.com/Hannick5/UrbanPerception)

# %%
img_left_training,img_right_training,label_training = data_aug_with_random_contrast(img_left_training,img_right_training, label_training,save_folder=None)

# %%
label_training = np.argmax(label_training, axis=1)
label_validation = np.argmax(label_validation, axis=1)
label_test = np.argmax(label_test, axis=1)

# %% [markdown]
# # Define hptuning model

# %%
# Define model for hyperparameters tuning
def build_hptuning_ranking_model(hp):
    # Define model architecture
    model = create_meta_network(
        dense_units=hp.Choice('dense_units', values=[32, 64, 128, 256, 512]),
        dropout_rate=hp.Float('dropout_rate', min_value=0.0, max_value=0.6, step=0.2),
        learning_rate=hp.Choice('learning_rate', values=[1e-4, 1e-5, 1e-6]),
        optimizer=hp.Choice('optimizer', values=['adam', 'rmsprop', 'sgd']),
        activation=hp.Choice('activation', values=['relu', 'tanh', 'sigmoid']),
        learning_rate_decay=hp.Choice('learning_rate_decay', values=[1e-3, 1e-4, 1e-5]),
        img_size=int(224),
        data_aug=True,
        weights=None
    )
    return model
build_hptuning_ranking_model(kt.HyperParameters())
# Adopt Bayesian optimization
tuner = kt.BayesianOptimization(
    build_hptuning_ranking_model,
    objective='val_accuracy',
    max_trials=20,
    executions_per_trial=4,
    overwrite=False,
    directory='model_results/Q'+ question_index +'/hptuning_ranking_model',
    project_name="ranking_model_prob_230723",
)
# Out:
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.

# %% [markdown]
# # Tune hyperparameters

# %%
# Employ early stopping to prevent overfitting
early_stopping = callbacks.EarlyStopping(
    monitor="val_loss",
    patience=10,
    mode='min',
    restore_best_weights=True
)

# Tune hyperparameters
tuner.search(
    x=[img_left_training, img_right_training],
    y=label_training,
    epochs=50,
    batch_size=32,
    validation_data=([img_left_validation, img_right_validation], label_validation),
    callbacks=[early_stopping]
)
# Out:
# Search: Running Trial #1
#
# Value             |Best Value So Far |Hyperparameter
# 64                |64                |dense_units
# 0.4               |0.4               |dropout_rate
# 1e-06             |1e-06             |learning_rate
# rmsprop           |rmsprop           |optimizer
# relu              |relu              |activation
# 0.001             |0.001             |learning_rate_decay
#
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# Epoch 1/50
# 172/172 [==============================] - 25s 118ms/step - loss: 1.1195 - accuracy: 0.5272 - val_loss: 0.7592 - val_accuracy: 0.6024
# Epoch 2/50
# 172/172 [==============================] - 18s 104ms/step - loss: 1.0181 - accuracy: 0.5599 - val_loss: 0.6940 - val_accuracy: 0.6353
# Epoch 3/50
# 172/172 [==============================] - 18s 102ms/step - loss: 0.9296 - accuracy: 0.5908 - val_loss: 0.6547 - val_accuracy: 0.6681
# Epoch 4/50
# 172/172 [==============================] - 18s 104ms/step - loss: 0.8861 - accuracy: 0.6217 - val_loss: 0.6264 - val_accuracy: 0.6867
# Epoch 5/50
# 172/172 [==============================] - 17s 102ms/step - loss: 0.8210 - accuracy: 0.6449 - val_loss: 0.6058 - val_accuracy: 0.7010
# Epoch 6/50
# 172/172 [==============================] - 18s 105ms/step - loss: 0.8067 - accuracy: 0.6434 - val_loss: 0.5863 - val_accuracy: 0.7152
# Epoch 7/50
# 172/172 [==============================] - 18s 102ms/step - loss: 0.7837 - accuracy: 0.6584 - val_loss: 0.5736 - val_accuracy: 0.7185
# Epoch 8/50
# 172/172 [==============================] - 17s 101ms/step - loss: 0.7615 - accuracy: 0.6715 - val_loss: 0.5641 - val_accuracy: 0.7251
# Epoch 9/50
# 172/172 [==============================] - 18s 104ms/step - loss: 0.7352 - accuracy: 0.6832 - val_loss: 0.5555 - val_accuracy: 0.7317
# Epoch 10/50
# 172/172 [==============================] - 17s 102ms/step - loss: 0.7408 - accuracy: 0.6743 - val_loss: 0.5469 - val_accuracy: 0.7371
# Epoch 11/50
# 172/172 [==============================] - 17s 102ms/step - loss: 0.7192 - accuracy: 0.6860 - val_loss: 0.5408 - val_accuracy: 0.7415
# Epoch 12/50
# 172/172 [==============================] - 17s 102ms/step - loss: 0.6904 - accuracy: 0.7031 - val_loss: 0.5347 - val_accuracy: 0.7448
# Epoch 13/50
# 172/172 [==============================] - 18s 102ms/step - loss: 0.6961 - accuracy: 0.7031 - val_loss: 0.5294 - val_accuracy: 0.7492
# Epoch 14/50
# 172/172 [==============================] - 18s 105ms/step - loss: 0.6641 - accuracy: 0.7075 - val_loss: 0.5250 - val_accuracy: 0.7503
# Epoch 15/50
# 172/172 [==============================] - 16s 96ms/step - loss: 0.6510 - accuracy: 0.7189 - val_loss: 0.5191 - val_accuracy: 0.7481
# Epoch 16/50
# 172/172 [==============================] - 18s 105ms/step - loss: 0.6430 - accuracy: 0.7130 - val_loss: 0.5157 - val_accuracy: 0.7536
# Epoch 17/50
# 172/172 [==============================] - 16s 96ms/step - loss: 0.6551 - accuracy: 0.7136 - val_loss: 0.5121 - val_accuracy: 0.7536
# Epoch 18/50
# 172/172 [==============================] - 18s 104ms/step - loss: 0.6414 - accuracy: 0.7203 - val_loss: 0.5093 - val_accuracy: 0.7558
# Epoch 19/50
# 172/172 [==============================] - 18s 102ms/step - loss: 0.6409 - accuracy: 0.7232 - val_loss: 0.5072 - val_accuracy: 0.7568
# Epoch 20/50
# 172/172 [==============================] - 18s 102ms/step - loss: 0.6259 - accuracy: 0.7242 - val_loss: 0.5050 - val_accuracy: 0.7590
# Epoch 21/50
# 172/172 [==============================] - 16s 95ms/step - loss: 0.6106 - accuracy: 0.7349 - val_loss: 0.5025 - val_accuracy: 0.7590
# Epoch 22/50
# 172/172 [==============================] - 18s 104ms/step - loss: 0.6260 - accuracy: 0.7269 - val_loss: 0.4986 - val_accuracy: 0.7667
# Epoch 23/50
# 172/172 [==============================] - 16s 96ms/step - loss: 0.6081 - accuracy: 0.7389 - val_loss: 0.4972 - val_accuracy: 0.7645
# Epoch 24/50
# 172/172 [==============================] - 18s 104ms/step - loss: 0.5956 - accuracy: 0.7446 - val_loss: 0.4942 - val_accuracy: 0.7689
# Epoch 25/50
# 172/172 [==============================] - 16s 96ms/step - loss: 0.5847 - accuracy: 0.7499 - val_loss: 0.4931 - val_accuracy: 0.7667
# Epoch 26/50
# 172/172 [==============================] - 18s 104ms/step - loss: 0.5879 - accuracy: 0.7441 - val_loss: 0.4914 - val_accuracy: 0.7700
# Epoch 27/50
# 172/172 [==============================] - 17s 102ms/step - loss: 0.5820 - accuracy: 0.7455 - val_loss: 0.4899 - val_accuracy: 0.7744
# Epoch 28/50
# 172/172 [==============================] - 16s 96ms/step - loss: 0.5714 - accuracy: 0.7521 - val_loss: 0.4887 - val_accuracy: 0.7700
# Epoch 29/50
# 172/172 [==============================] - 16s 95ms/step - loss: 0.5813 - accuracy: 0.7501 - val_loss: 0.4877 - val_accuracy: 0.7744
# Epoch 30/50
# 172/172 [==============================] - 16s 96ms/step - loss: 0.6017 - accuracy: 0.7428 - val_loss: 0.4856 - val_accuracy: 0.7744
# Epoch 31/50
# 172/172 [==============================] - 18s 105ms/step - loss: 0.5836 - accuracy: 0.7510 - val_loss: 0.4832 - val_accuracy: 0.7798
# Epoch 32/50
# 172/172 [==============================] - 16s 95ms/step - loss: 0.5601 - accuracy: 0.7567 - val_loss: 0.4835 - val_accuracy: 0.7798
# Epoch 33/50
# 172/172 [==============================] - 18s 104ms/step - loss: 0.5561 - accuracy: 0.7521 - val_loss: 0.4799 - val_accuracy: 0.7809
# Epoch 34/50
# 172/172 [==============================] - 17s 102ms/step - loss: 0.5578 - accuracy: 0.7578 - val_loss: 0.4783 - val_accuracy: 0.7842
# Epoch 35/50
# 172/172 [==============================] - 16s 95ms/step - loss: 0.5623 - accuracy: 0.7563 - val_loss: 0.4794 - val_accuracy: 0.7831
# Epoch 36/50
# 172/172 [==============================] - 16s 95ms/step - loss: 0.5511 - accuracy: 0.7579 - val_loss: 0.4789 - val_accuracy: 0.7798
# Epoch 37/50
# 172/172 [==============================] - 18s 104ms/step - loss: 0.5438 - accuracy: 0.7614 - val_loss: 0.4766 - val_accuracy: 0.7864
# Epoch 38/50
# 172/172 [==============================] - 17s 102ms/step - loss: 0.5542 - accuracy: 0.7589 - val_loss: 0.4745 - val_accuracy: 0.7897
# Epoch 39/50
# 172/172 [==============================] - 17s 101ms/step - loss: 0.5476 - accuracy: 0.7667 - val_loss: 0.4748 - val_accuracy: 0.7919
# Epoch 40/50
# 172/172 [==============================] - 16s 96ms/step - loss: 0.5391 - accuracy: 0.7643 - val_loss: 0.4737 - val_accuracy: 0.7886
# Epoch 41/50
# 172/172 [==============================] - 16s 96ms/step - loss: 0.5468 - accuracy: 0.7632 - val_loss: 0.4735 - val_accuracy: 0.7897
# Epoch 42/50
# 172/172 [==============================] - 16s 96ms/step - loss: 0.5578 - accuracy: 0.7621 - val_loss: 0.4720 - val_accuracy: 0.7886
# Epoch 43/50
# 172/172 [==============================] - 16s 96ms/step - loss: 0.5288 - accuracy: 0.7647 - val_loss: 0.4710 - val_accuracy: 0.7897
# Epoch 44/50
# 172/172 [==============================] - 6839s 40s/step - loss: 0.5571 - accuracy: 0.7572 - val_loss: 0.4697 - val_accuracy: 0.7941
# Epoch 45/50
# 172/172 [==============================] - 17s 101ms/step - loss: 0.5414 - accuracy: 0.7684 - val_loss: 0.4708 - val_accuracy: 0.7897
# Epoch 46/50
# 172/172 [==============================] - 16s 96ms/step - loss: 0.5427 - accuracy: 0.7696 - val_loss: 0.4696 - val_accuracy: 0.7908
# Epoch 47/50
# 129/172 [=====================>........] - ETA: 3s - loss: 0.5177 - accuracy: 0.7759

# %% [markdown]
# # Obtain hptuning results

# %%
# Display the tuning process summary
tuner.results_summary()

# %%
# Save the best five hptuned model architectures
best_hps = tuner.get_best_hyperparameters(5)
save_dir = "model_results/Q2/hp_tuning/hptuning_ranking_230521"
for i in range(len(best_hps)):
    model = build_hptuning_ranking_model(best_hps[i])
    model.save(os.path.join(save_dir, 'best_model_' + str(i) + '_architecture.h5'))
